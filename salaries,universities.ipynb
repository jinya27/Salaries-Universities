# %% [markdown]
# <a href="https://colab.research.google.com/github/jinya27/Salaries-Universities/blob/main/salaries%2Cuniversities.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
print(df)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#first 5 records in dataset
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
#to display first 10 records
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.tail()
# Out:
#          rank discipline  phd  service     sex  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.tail(10)
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.shape
# Out:
# (78, 6)

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# ..    ...         ...    ...      ...    ...     ...
# 73  False       False  False    False  False   False
# 74  False       False  False    False  False   False
# 75  False       False  False    False  False   False
# 76  False       False  False    False  False   False
# 77  False       False  False    False  False   False
#
# [78 rows x 6 columns]

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.isnull()
# Out:
#      rank  discipline    phd  service    sex  salary
# 0   False       False  False    False  False   False
# 1   False       False  False    False  False   False
# 2   False       False  False    False  False   False
# 3   False       False  False    False  False   False
# 4   False       False  False    False  False   False
# 5   False       False  False    False  False   False
# 6   False       False  False    False  False   False
# 7   False       False  False    False  False   False
# 8   False       False  False    False  False   False
# 9   False       False  False    False  False   False
# 10  False       False  False    False  False   False
# 11  False       False  False    False  False   False
# 12  False       False  False    False  False   False
# 13  False       False  False    False  False   False
# 14  False       False  False    False  False   False
# 15  False       False  False    False  False   False
# 16  False       False  False    False  False   False
# ...

# %%
#to check for null values
df.isnull().sum()
# Out:
# rank          0
# discipline    0
# phd           0
# service       0
# sex           0
# salary        0
# dtype: int64

# %%
df.count()
# Out:
# rank          78
# discipline    78
# phd           78
# service       78
# sex           78
# salary        78
# dtype: int64

# %%
import warnings
warnings.filterwarnings('ignore')
# Calculate the mean of the DataFrame
df_mean = df.select_dtypes(include='number').mean()
print(df_mean)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df['salary'].mean()
# Out:
# 108023.78205128205

# %%
df['salary'].median()
# Out:
# 104671.0

# %%
df['salary'].mode()[0]
# Out:
# 92000

# %%
df['salary'].var()
# Out:
# 800531254.0427904

# %%
df['salary'].std()
# Out:
# 28293.661022264165

# %%
df['salary'].min()
# Out:
# 57800

# %%
df['salary'].max()
# Out:
# 186960

# %%
df['salary'].skew()
# Out:
# 0.45210256755588096

# %%
df['salary'].kurt()
# Out:
# -0.4017126758820546

# %%
df[df['salary']>50000]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df['salary']
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
# 5     122400
# 6      81285
# 7     126300
# 8      94350
# 9      57800
# 10    128250
# 11    134778
# 12     88000
# 13    162200
# 14    153750
# 15    150480
# 16     75044
# 17     92000
# 18    107300
# 19    150500
# 20     92000
# 21    103106
# 22     73000
# 23     85000
# 24     91100
# 25     99418
# 26    148750
# 27    155865
# 28     91300
# 29    123683
# 30    107008
# 31    155750
# 32    103275
# 33    120000
# 34    119800
# 35    126933
# 36    146856
# 37    102000
# 38     91000
# 39    129000
# 40    137000
# 41     74830
# 42     80225
# 43     77000
# 44    151768
# 45    140096
# 46     74692
# 47    103613
# 48    111512
# 49    122960
# 50     97032
# 51    127512
# 52    105000
# 53     73500
# 54     62884
# 55     72500
# 56     77500
# 57     72500
# 58    144651
# 59    103994
# 60     92000
# 61    103750
# 62    109650
# 63     91000
# 64     73300
# 65    117555
# ...

# %%
df[['salary','service', 'phd']]
# Out:
#     salary  service  phd
# 0   186960       49   56
# 1    93000        6   12
# 2   110515       20   23
# 3   131205       31   40
# 4   104800       18   20
# 5   122400       20   20
# 6    81285       17   20
# 7   126300       18   18
# 8    94350       19   29
# 9    57800       51   51
# 10  128250       33   39
# 11  134778       23   23
# 12   88000        0    1
# 13  162200       33   35
# 14  153750       19   25
# 15  150480        3   17
# 16   75044        3    8
# 17   92000        0    4
# 18  107300        7   19
# 19  150500       27   29
# 20   92000        4    4
# 21  103106       30   33
# 22   73000        2    4
# 23   85000        0    2
# 24   91100       23   30
# 25   99418       31   35
# 26  148750       19   38
# 27  155865       43   45
# 28   91300        2    7
# 29  123683       20   21
# 30  107008        7    9
# 31  155750       21   22
# 32  103275       19   27
# 33  120000       18   18
# 34  119800        8   12
# 35  126933       23   28
# ...

# %%
df['rank'].value_counts()
# Out:
# rank
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: count, dtype: int64

# %%
df.min()
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
#it shows all rows nd columns
df.iloc[:,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
#first 50 records and all the columns
df.iloc[0:50,:]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.iloc[0:50, 0:4]
# Out:
#          rank discipline  phd  service
# 0        Prof          B   56       49
# 1        Prof          A   12        6
# 2        Prof          A   23       20
# 3        Prof          A   40       31
# 4        Prof          B   20       18
# 5        Prof          A   20       20
# 6   AssocProf          A   20       17
# 7        Prof          A   18       18
# 8        Prof          A   29       19
# 9        Prof          A   51       51
# 10       Prof          B   39       33
# 11       Prof          B   23       23
# 12   AsstProf          B    1        0
# 13       Prof          B   35       33
# 14       Prof          B   25       19
# 15       Prof          B   17        3
# 16   AsstProf          B    8        3
# 17   AsstProf          B    4        0
# 18       Prof          A   19        7
# 19       Prof          A   29       27
# 20   AsstProf          B    4        4
# 21       Prof          A   33       30
# 22   AsstProf          A    4        2
# ...

# %%
df.iloc[0:50,[1,2,4]]
# Out:
#    discipline  phd     sex
# 0           B   56    Male
# 1           A   12    Male
# 2           A   23    Male
# 3           A   40    Male
# 4           B   20    Male
# 5           A   20    Male
# 6           A   20    Male
# 7           A   18    Male
# 8           A   29    Male
# 9           A   51    Male
# 10          B   39    Male
# 11          B   23    Male
# 12          B    1    Male
# 13          B   35    Male
# 14          B   25    Male
# 15          B   17    Male
# 16          B    8    Male
# 17          B    4    Male
# 18          A   19    Male
# 19          A   29    Male
# 20          B    4    Male
# 21          A   33    Male
# 22          A    4    Male
# 23          A    2    Male
# 24          A   30    Male
# 25          B   35    Male
# 26          A   38    Male
# 27          A   45    Male
# 28          B    7    Male
# 29          B   21    Male
# 30          B    9    Male
# 31          B   22    Male
# 32          A   27    Male
# ...

# %%
df.loc[0,'phd']
# Out:
# 56

# %%
import pandas as pd
# Select only numeric columns for calculating the mean
numeric_df = df.select_dtypes(include=['number'])
# Calculate the mean of the numeric columns
mean_values = numeric_df.mean()
print(mean_values)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
# Convert the 'phd' column to numeric if it contains numeric strings
df['phd'] = pd.to_numeric(df['phd'], errors='coerce')
# Group by 'rank' and calculate the mean, excluding non-numeric columns
result = df.groupby('rank').mean(numeric_only=True)
print(result)
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
result = df.groupby(by ='rank')[['salary','service']].mean()
print(result)
# Out:
#                   salary    service
# rank
# AssocProf   91786.230769  11.307692
# AsstProf    81362.789474   2.210526
# Prof       123624.804348  21.413043

# %%
df1 = pd.read_csv('Salaries.csv', nrows = 10)

# %%
df1
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df2 = df.copy()

# %%
df2
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/Universities.csv')

# %%
df
# Out:
#             Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0          Brown  1310     89      22       13     22704        94
# 1        CalTech  1415    100      25        6     63575        81
# 2            CMU  1260     62      59        9     25026        72
# 3       Columbia  1310     76      24       12     31510        88
# 4        Cornell  1280     83      33       13     21864        90
# 5      Dartmouth  1340     89      23       10     32162        95
# 6           Duke  1315     90      30       12     31585        95
# 7     Georgetown  1255     74      24       12     20126        92
# 8        Harvard  1400     91      14       11     39525        97
# 9   JohnsHopkins  1305     75      44        7     58691        87
# 10           MIT  1380     94      30       10     34870        91
# 11  Northwestern  1260     85      39       11     28052        89
# 12     NotreDame  1255     81      42       13     15122        94
# ...

# %%
df.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate'], dtype='object')

# %%
df.shape
# Out:
# (25, 7)

# %%
#refer to column
df['Univ']
# Out:
# 0            Brown
# 1          CalTech
# 2              CMU
# 3         Columbia
# 4          Cornell
# 5        Dartmouth
# 6             Duke
# 7       Georgetown
# 8          Harvard
# 9     JohnsHopkins
# 10             MIT
# 11    Northwestern
# 12       NotreDame
# 13       PennState
# 14       Princeton
# 15          Purdue
# 16        Stanford
# 17        TexasA&M
# 18      UCBerkeley
# 19        UChicago
# 20       UMichigan
# 21           UPenn
# 22             UVA
# 23      UWisconsin
# 24            Yale
# Name: Univ, dtype: object

# %%
#refer to column
df.Univ
# Out:
# 0            Brown
# 1          CalTech
# 2              CMU
# 3         Columbia
# 4          Cornell
# 5        Dartmouth
# 6             Duke
# 7       Georgetown
# 8          Harvard
# 9     JohnsHopkins
# 10             MIT
# 11    Northwestern
# 12       NotreDame
# 13       PennState
# 14       Princeton
# 15          Purdue
# 16        Stanford
# 17        TexasA&M
# 18      UCBerkeley
# 19        UChicago
# 20       UMichigan
# 21           UPenn
# 22             UVA
# 23      UWisconsin
# 24            Yale
# Name: Univ, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
#excluded our 1st column
df = df.iloc[:, 1:]

# %%
df
# Out:
#      SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0   1310     89      22       13     22704        94
# 1   1415    100      25        6     63575        81
# 2   1260     62      59        9     25026        72
# 3   1310     76      24       12     31510        88
# 4   1280     83      33       13     21864        90
# 5   1340     89      23       10     32162        95
# 6   1315     90      30       12     31585        95
# 7   1255     74      24       12     20126        92
# 8   1400     91      14       11     39525        97
# 9   1305     75      44        7     58691        87
# 10  1380     94      30       10     34870        91
# 11  1260     85      39       11     28052        89
# 12  1255     81      42       13     15122        94
# 13  1081     38      54       18     10185        80
# 14  1375     91      14        8     30220        95
# 15  1005     28      90       19      9066        69
# 16  1360     90      20       12     36450        93
# ...

# %%
df.describe()
# Out:
#                SAT       Top10     Accept   SFRatio      Expenses   GradRate
# count    25.000000   25.000000  25.000000  25.00000     25.000000  25.000000
# mean   1266.440000   76.480000  39.200000  12.72000  27388.000000  86.720000
# std     108.359771   19.433905  19.727308   4.06735  14424.883165   9.057778
# min    1005.000000   28.000000  14.000000   6.00000   8704.000000  67.000000
# 25%    1240.000000   74.000000  24.000000  11.00000  15140.000000  81.000000
# 50%    1285.000000   81.000000  36.000000  12.00000  27553.000000  90.000000
# 75%    1340.000000   90.000000  50.000000  14.00000  34870.000000  94.000000
# max    1415.000000  100.000000  90.000000  25.00000  63575.000000  97.000000

# %%
df.isnull().sum()
# Out:
# SAT         0
# Top10       0
# Accept      0
# SFRatio     0
# Expenses    0
# GradRate    0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.hist(df['SAT'])
plt.title('Distribution of SAT Scores')
plt.show()

# %%
plt.hist(df['Top10'])
plt.show()

# %%
plt.hist(df['Accept'])
plt.show()

# %%
sns.histplot(df['SAT']) #sns imports seaborn library, #This function creates a histogram plot
plt.show()

# %%
sns.histplot(df['Accept'])
plt.show()

# %%
plt.plot(df['SAT'],df['Accept'], 'go') #go represents shape nd color
plt.xlabel('SAT')
plt.ylabel('Accept')
plt.title('Scatterplot')
plt.show()

# %%
plt.plot(df['SAT'],df['Top10'], 'rs')
plt.xlabel('SAT')
plt.ylabel('Top10')
plt.title('Scatterplot')
plt.show()

# %%
sns.pairplot(df)

# %%
sns.pairplot(df.iloc[:,0:4])

# %%
plt.figure(figsize = (5,5))
plt.boxplot(df['SAT'])
plt.show()

# %%
plt.figure(figsize = (5,5))
plt.boxplot(df['Accept'])
plt.show()

# %%
plt.figure(figsize = (5,5))
plt.boxplot(df['SAT'], vert = False)
plt.xlabel('SAT')
plt.ylabel('Values')
plt.title('Boxplot')
plt.show()

# %%
sns.distplot(df['SAT'])
plt.show()

# %%
sns.distplot(df['Accept'])
plt.show()

# %%
import numpy as np
a = np.array([1,2,3,4])
type(a)
# Out:
# numpy.ndarray

# %%
a.shape # 4 elemets in array
# Out:
# (4,)

# %%
a.size # it shows how many values we're having
# Out:
# 4

# %%
a.sum() #sum of elements in our array
# Out:
# 10

# %%
a.prod() #gives the product
# Out:
# 24

# %%
a.min() #it gives min value
# Out:
# 1

# %%
a.max() #it gives max value
# Out:
# 4

# %%
b=np.array([(1,2,3,4),(4,5,6,7)]) #1 D-Array
b
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.shape
# Out:
# (2, 4)

# %%
b.size #it gives the no.of elements present in an array
# Out:
# 8

# %%
b=b.reshape(4,2) #reshapes it into 4-rows , 2-columns
b
# Out:
# array([[1, 2],
#        [3, 4],
#        [4, 5],
#        [6, 7]])

# %%
b[0]
# Out:
# array([1, 2])

# %%
b[0,0] #based on the indexing it gives the value
# Out:
# 1

# %%
b[0,1]
# Out:
# 2

# %%
b.sum(axis=0) #it gives sum of elements in first row nd second row
# Out:
# array([14, 18])

# %%
b.sum(axis=1) #it gives sum of elements in first col nd second col
# Out:
# array([ 3,  7,  9, 13])
